# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})

# %%
sapo = "https://www.bezrealitky.cz/nemovitosti-byty-domy/539200-nabidka-prodej-bytu-tetinska-hlavni-mesto-praha"
response = get(sapo, headers=headers)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="cs" class="no-js" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#     <head>
#         <script>
#                 window.dataLayer = window.dataLayer || [];
#             </script><script>
#         dataLayer.push({"pageType":"inzerat_prodej","equipped":"\u010c\u00e1ste\u010dn\u011b","price":7495000,"currency":"CZK","status":"active","geo1":"Praha","geo2":"Radlice"});
#     </script><script>
#                 var userId = '';
#                 if (userId !== '') {
#                     dataLayer.push({'userID': userId});
#                 }
#             </script><!-- Google Tag Manager --><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-TTKNMZ');</script><!-- End Google Tag Maager -->
#         <meta charset="utf-8">
#         <meta http-equiv="Content-Type" content="text/html; charset=utf-8" >
#         <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><![endif]-->
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=0">
#         <meta name="author" content="Bezrealitky" >
#         <meta name="mobile-web-app-capable" content="yes">
#         <meta name="format-detection" content="telephone=no">
#
#         <meta name="description" content="Inzerát č. 539200 - Tento krásný byt leží na památném kopci Dívčí Hrady v Praze 5. Přes ulici začíná  Národní přírodní..." >
#         <meta name="keywords" content="Prodej bytu Tetínská 3+kk bez RK" >
#
#         <meta property="og:title" content="Prodej bytu Tetínská 3+kk bez RK">
#         <meta property="og:description" content="Tento krásný byt leží na památném kopci Dívčí Hrady v Praze 5. Přes ulici začíná  Národní přírodní památka Prokopské údolí, které je úžasné na procházky, běhání,...">
#         <meta property="og:image" content="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532840-gbkfzblzrc.jpg">
#
#                 <meta name="apple-itunes-app" content="app-id=1444343291">
#
#
#                     <link rel="canonical" href="https://www.bezrealitky.cz/nemovitosti-byty-domy/539200-nabidka-prodej-bytu-tetinska-hlavni-mesto-praha" />
#
#
#
#                                                                                                                                         <link rel="alternate" hreflang="sk" href="https://www.bezrealitky.sk/nehnutelnosti-byty-domy/539200-nabidka-prodej-bytu-tetinska-hlavni-mesto-praha" />
#
#
#         <title>Prodej bytu Tetínská 3+kk bez RK | Bezrealitky</title>
#
#
#         <link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:300,400,700|Roboto:300,400,500,700&amp;subset=latin-ext" rel="stylesheet">
#         <link rel="stylesheet" href="/build/style.41e51a93.css" media="screen">
#         <link rel="stylesheet" href="/build/print.c70d9a6e.css" media="print">
#         <link rel="shortcut icon" href="/img/favicon.ico">
#
#         <!-- favicons -->
#         <link rel="apple-touch-icon" sizes="57x57" href="/img/favicons/apple-touch-icon-57x57.png">
#         <link rel="apple-touch-icon" sizes="60x60" href="/img/favicons/apple-touch-icon-60x60.png">
#         <link rel="apple-touch-icon" sizes="72x72" href="/img/favicons/apple-touch-icon-72x72.png">
#         <link rel="apple-touch-icon" sizes="76x76" href="/img/favicons/apple-touch-icon-76x76.png">
#         <link rel="apple-touch-icon" sizes="114x114" href="/img/favicons/apple-touch-icon-114x114.png">
#         <link rel="apple-touch-icon" sizes="120x120" href="/img/favicons/apple-touch-icon-120x120.png">
#         <link rel="apple-touch-icon" sizes="144x144" href="/img/favicons/apple-touch-icon-144x144.png">
#         <link rel="apple-touch-icon" sizes="152x152" href="/img/favicons/apple-touch-icon-152x152.png">
#         <link rel="apple-touch-icon" sizes="180x180" href="/img/favicons/apple-touch-icon-180x180.png">
#         <link rel="icon" type="image/png" href="/img/favicons/favicon-32x32.png" sizes="32x32">
#         <link rel="icon" type="image/png" href="/img/favicons/android-chrome-192x192.png" sizes="192x192">
#         <link rel="icon" type="image/png" href="/img/favicons/favicon-96x96.png" sizes="96x96">
#         <link rel="icon" type="image/png" href="/img/favicons/favicon-16x16.png" sizes="16x16">
#         <link rel="manifest" href="/img/favicons/manifest.json?version=1557930552">
#         <link rel="mask-icon" href="/img/favicons/safari-pinned-tab.svg" color="#5bbad5">
#         <link rel="shortcut icon" href="/img/favicons/favicon.ico">
#         <meta name="msapplication-TileColor" content="#da532c">
#         <meta name="msapplication-TileImage" content="/img/favicons/mstile-144x144.png">
#         <meta name="msapplication-config" content="/img/favicons/browserconfig.xml">
#         <meta name="theme-color" content="#ffffff">
#
#
#         <script src="/js/localStorage.js?version=1557930552"></script>
#
#                         <link rel="stylesheet" type="text/css" href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css"/>
#         <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
#
#         <script>
#             (function () {
#                 var className = document.documentElement.className;
#                 className = className.replace('no-js', 'js');
#
#                 if (window.name.indexOf('fontsLoaded=true') > -1) {
#                     className += ' fonts-loaded';
#                 }
#
#                 document.documentElement.className = className;
#             }());
#         </script>
#         <script src="//assets.adobedtm.com/4beaca54604aa1db7a7d9296a08d83bee398e7fd/satelliteLib-b54c24dc1fb24a614f18cbe602726d4b06972d15.js"></script>
#     </head>
#
#     <body class="web-view no-header-sticky std-view">
#                     <!-- Google Tag Manager (noscript) -->
#             <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-TTKNMZ"
#             height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#             <!-- End Google Tag Manager (noscript) -->
#
#                     <!-- (C)2000-2018 Gemius SA - gemiusPrism  / http://www.bezrealitky.cz/Ostatni -->
#             <script type="text/javascript">
#                 <!--//--><![CDATA[//><!--
#                 var pp_gemius_identifier = '.F3glHw893Utgx0ddubFTHZGTBN10oRJTrxG9VY8EXL.n7';
#                 // lines below shouldn't be edited
#                 function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};gemius_pending('gemius_hit'); gemius_pending('gemius_event'); gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');(function(d,t) {try {var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':''); gt.setAttribute('async','async');gt.setAttribute('defer','defer'); gt.src=l+'://spir.hit.gemius.pl/xgemius.js'; s.parentNode.insertBefore(gt,s);} catch (e) {}})(document,'script');
#                 //--><!]]>
#             </script>
#
#         <script type="text/javascript">
#             function setCookie(c_name, value, exdays) {
#                 var exdate = new Date();
#                 exdate.setDate(exdate.getDate() + exdays);
#                 var c_value = escape(value) + ((exdays === null) ? "" : "; expires=" + exdate.toUTCString());
#                 document.cookie = c_name + "=" + c_value;
#             }
#         </script>
#
#
#         <div class="mother">
#
#                             <header role="banner" class="header " data-trigger="trigger-header">
#     <div class="header__holder">
#
#
#         <div class="header__wrap">
#             <p class="header__logo">
#                 <a href="/">
#                     <img src="/img/logo-bezrealitky.svg" alt="Bezrealitky" width="193" height="33">
#                 </a>
#             </p>
#
#             <div class="header__container container-fluid">
#                 <nav class="m-main dropdown is-hide">
#                     <a href="#" class="m-main__title btn btn-secondary btn-icon btn-sm btn-shadow" data-toggle="dropdown">
#                         <span class="btn__icon">
#                             <span class="icon-svg icon-svg--logo-burger ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-logo-burger" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            <span class="icon-svg icon-svg--logo-cross ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-logo-cross" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                        </span>
#                         Menu
#                     </a>
#
#                     <div class="m-main__wrap dropdown-menu left-130">
#                         <ul class="nav m-main__list">
#                             <li class="nav-item m-main__item">
#                                 <a class="nav-link m-main__link " href="/vyhledat">
#                                     Vyhledat
#                                 </a>
#                             </li>
#                             <li class="nav-item m-main__item">
#                                 <a class="nav-link m-main__link " href="/vypis/nabidka-prodej/byt">
#                                     Výpis inzerátů
#                                 </a>
#                             </li>
#                             <li class="nav-item m-main__item">
#                                 <a class="nav-link m-main__link " href="/informace/cenik-sluzeb">
#                                     Ceník inzerce
#                                 </a>
#                             </li>
#                             <li class="nav-item m-main__item">
#                                 <a class="nav-link m-main__link " href="/centrum-sluzeb">
#                                     Služby
#                                 </a>
#                             </li>
#                             <li class="nav-item m-main__item">
#                                 <a class="nav-link m-main__link " href="/vlozit-inzerat">
#                                     Vložit inzerát
#                                 </a>
#                             </li>
#                         </ul>
#
#                         <nav class="m-side">
#                             <ul class="nav flex-column m-side__list">
#                                 <li class="nav-item m-side__item">
#                                     <a class="nav-link m-side__link" href="/moje-bezrealitky">
#                                         <span class="icon-svg icon-svg--summary ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-summary" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                        Přehled
#                                     </a>
#                                 </li>
#                                 <li class="nav-item m-side__item">
#                                     <a class="nav-link m-side__link active" href="/moje-bezrealitky/zpravy">
#                                         <span class="icon-svg icon-svg--message ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-message" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                        Zprávy
#                                                                             </a>
#                                 </li>
#                                 <li class="nav-item m-side__item">
#                                     <a class="nav-link m-side__link" href="/moje-bezrealitky/upozorneni">
#                                         <span class="icon-svg icon-svg--bell ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-bell" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                        Upozornění
#                                                                             </a>
#                                 </li>
#                                 <li class="nav-item m-side__item">
#                                     <a class="nav-link m-side__link" href="/moje-bezrealitky/oblibene">
#                                         <span class="icon-svg icon-svg--favorite ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-favorite" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                        Oblíbené inzeráty
#                                                                             </a>
#                                 </li>
#                                 <li class="nav-item m-side__item">
#                                     <a class="nav-link m-side__link" href="/moje-bezrealitky/hlidaci-pes">
#                                         <span class="icon-svg icon-svg--dog ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-dog" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                        Hlídací pes
#                                                                             </a>
#                                 </li>
#                             </ul>
#                         </nav>
#                     </div>
#                 </nav>
#             </div>
#
#                                         <nav class="m-profile" role="navigation">
#                     <ul class="nav m-profile__list">
#                         <li class="nav-item m-profile__item m-profile__item--log dropdown">
#                             <a class="nav-link m-profile__link" data-toggle="" href="/prihlaseni">
#                                 <span class="m-profile__label">
#                                     <span class="item-ico item-ico--before">
#                                         <span class="icon-svg icon-svg--user-sharp ">
#                                             <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                                 <use xlink:href="/img/bg/icons-svg.svg#icon-user-sharp" x="0" y="0" width="100%" height="100%"></use>
#                                             </svg>
#                                         </span>
#                                         Přihlášení
#                                     </span>
#                                 </span>
#                             </a>
#
#                             <div class="m-profile__wrap dropdown-menu">
#                                 <div class="c-reset">
#                                     <div class="row c-reset__list">
#                                         <div class="col col-12 col-md-6 c-reset__item">
#                                             <div class="modal-body p-30">
#                                                 <form action="/login-check">
#                                                     <input type="hidden" name="_target_path" value="https://www.bezrealitky.cz/nemovitosti-byty-domy/539200-nabidka-prodej-bytu-tetinska-hlavni-mesto-praha">
#
#                                                     <div class="form-group">
#                                                         <label>E-mail:</label>
#                                                         <input type="email" class="form-control" name="_username">
#                                                     </div>
#
#                                                     <div class="form-group mb-20">
#                                                         <a href="#" class="float-right">Zapomenuté heslo</a>
#                                                         <label>Heslo:</label>
#                                                         <input type="password" class="form-control" name="_password" autocomplete="false">
#                                                     </div>
#
#                                                     <p>Přihlášením potvrzuji, že nejsem realitní makléř. Pokud je mé prohlášení nepravdivé, může mi být udělena pokuta dle <a href="/informace/smluvni-podminky">smluvních podmínek</a>.</p>
#
#                                                     <div class="form-group mb-25">
#                                                         <button type="submit" class="btn btn-primary btn-shadow btn-block">
#                                                             Přihlásit se
#                                                         </button>
#                                                     </div>
#                                                 </form>
#                                             </div>
#                                         </div>
#
#                                         <div class="col col-12 col-md-6 c-reset__item">
#                                             <div class="modal-body p-30 modal-body--blue">
#                                                 <h3 class="h5 mb-25">Nemáte ještě účet? <br/>Registrujte se</h3>
#                                                 <p class="mb-20">
#                                                     <span class="item-ico item-ico--badge">
#                                                         <span class="badge badge-icon badge-md badge-circle badge-shadow">
#                                                             <span class="icon-svg icon-svg--check ">
#                                                                 <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                                                     <use xlink:href="/img/bg/icons-svg.svg#icon-check" x="0" y="0" width="100%" height="100%"></use>
#                                                                 </svg>
#                                                             </span>
#
#                                                         </span>
#                                                         Můžete <strong>kontaktovat</strong> majitele a <strong>založit si profil</strong><br/><a href="/centrum-sluzeb/uzivatelske-ucty">(od 99 Kč/3 měsíce)</a>
#                                                     </span>
#                                                 </p>
#
#                                                 <p class="mb-20">
#                                                     <span class="item-ico item-ico--badge">
#                                                         <span class="badge badge-icon badge-md badge-circle badge-shadow">
#                                                             <span class="icon-svg icon-svg--check ">
#                                                                 <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                                                     <use xlink:href="/img/bg/icons-svg.svg#icon-check" x="0" y="0" width="100%" height="100%"></use>
#                                                                 </svg>
#                                                             </span>
#
#                                                         </span>
#                                                         Nastavíte si <strong>hlidacího psa</strong>
#                                                     </span>
#                                                 </p>
#                                                 <p class="mb-20">
#                                                     <span class="item-ico item-ico--badge">
#                                                         <span class="badge badge-icon badge-md badge-circle badge-shadow">
#                                                             <span class="icon-svg icon-svg--check ">
#                                                                 <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                                                     <use xlink:href="/img/bg/icons-svg.svg#icon-check" x="0" y="0" width="100%" height="100%"></use>
#                                                                 </svg>
#                                                             </span>
#
#                                                         </span>
#                                                         Uložíte si <strong>oblíbené</strong> inzeráty
#                                                     </span>
#                                                 </p>
#                                                 <p class="mb-20">
#                                                     <span class="item-ico item-ico--badge">
#                                                         <span class="badge badge-icon badge-md badge-circle badge-shadow">
#                                                             <span class="icon-svg icon-svg--check ">
#                                                                 <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                                                     <use xlink:href="/img/bg/icons-svg.svg#icon-check" x="0" y="0" width="100%" height="100%"></use>
#                                                                 </svg>
#                                                             </span>
#
#                                                         </span>
#                                                         Můžete <strong>vložit</strong> inzeráty<br/><a href="/informace/cenik-sluzeb">(od 199 Kč/měsíc)</a>
#                                                     </span>
#                                                 </p>
#
#                                                 <p class="mb-20">
#                                                     <span class="item-ico item-ico--badge">
#                                                         <span class="badge badge-icon badge-md badge-circle badge-shadow">
#                                                             <span class="icon-svg icon-svg--check ">
#                                                                 <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                                                     <use xlink:href="/img/bg/icons-svg.svg#icon-check" x="0" y="0" width="100%" height="100%"></use>
#                                                                 </svg>
#                                                             </span>
#
#                                                         </span>
#                                                         Sledujete <strong>statistiku návštěvnosti</strong>
#                                                     </span>
#                                                 </p>
#
#                                                 <a href="/registrace" class="btn btn-secondary btn-shadow btn-block mt-md-80">
#                                                     Registrovat
#                                                 </a>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#                         </li>
#
#                                                                                                                                                             </ul>
#                 </nav>
#                     </div>
#     </div>
# </header>
#
#                 <main role="main" class="main">
#         <article role="article" class="js-fancybox">
#             <div class="b-bg">
#                 <div class="main__container container-fluid">
#                     <div class="breadcrumbs mb-20">
#     <ul class="breadcrumbs-list">
#                                     <li itemscope itemtype="http://data-vocabulary.org/Breadcrumb">
#                     <a href="/" class="breadcrumbs__link" itemprop="url">
#                         <span itemprop="title">
#                             Hlavní&nbsp;stránka
#                         </span>
#                     </a>
#                 </li>
#                                                 <li itemscope itemtype="http://data-vocabulary.org/Breadcrumb">
#                     <a href="/vypis/nabidka-prodej/byt" class="breadcrumbs__link" itemprop="url">
#                         <span itemprop="title">
#                             Nabídka&nbsp;prodej
#                         </span>
#                     </a>
#                 </li>
#                                                 <li itemscope itemtype="http://data-vocabulary.org/Breadcrumb">
#                     <a href="/vypis/nabidka-prodej/byt" class="breadcrumbs__link" itemprop="url">
#                         <span itemprop="title">
#                             Byt
#                         </span>
#                     </a>
#                 </li>
#                                                 <li itemscope itemtype="http://data-vocabulary.org/Breadcrumb">
#                     <a href="/vypis/nabidka-prodej/byt/praha" class="breadcrumbs__link" itemprop="url">
#                         <span itemprop="title">
#                             Praha
#                         </span>
#                     </a>
#                 </li>
#                                                 <li itemscope itemtype="http://data-vocabulary.org/Breadcrumb">
#                     <a href="/vypis/nabidka-prodej/byt/praha/praha-radlice" class="breadcrumbs__link" itemprop="url">
#                         <span itemprop="title">
#                             Radlice
#                         </span>
#                     </a>
#                 </li>
#                                                 <li>
#                     <span class="breadcrumbs__item">
#                         Prodej&nbsp;bytu&nbsp;&nbsp;3+kk&nbsp;bez&nbsp;realitky
#                     </span>
#                 </li>
#                         </ul>
# </div>
#                     <div class="heading">
#                         <div class="heading__wrap">
#                             <h1 class="heading__title" data-fancybox-title="">
#                                 <span>Prodej bytu  3+kk bez realitky</span>
#                                 <br>
#                                 <span class="heading__perex font-weight-medium" data-fancybox-description="">
#                                     Tetínská, Praha - Radlice
#                                 </span>
#                             </h1>
#                         </div>
#                         <p class="heading__side" data-fancybox-price>
#                             7.495.000 Kč
#                         </p>
#                     </div>
#                 </div>
#             </div>
#
#             <div class="main__container container-fluid bg-white">
#                 <div class="row">
#                     <div class="col col-12 col-md-8 col-print-12">
#
#                         <div class="b-gallery carousel mt-minus">
#
#
#                                                         <div class="b-gallery__img-lg carousel__wrap">
#                                 <div class="carousel__list b-gallery__fancybox slick-detail-preview js-fancybox-gallery">
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532840-gbkfzblzrc.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532840-gbkfzblzrc.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 1" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508868-piwlwuivqr.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508868-piwlwuivqr.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 2" width="820" height="545">
#                                         </a>
#
#                                                                                     <a href="/img/innogy/780x500_banner_cs.jpg"
#                                                class="carousel__item b-gallery__img-lg__item gallery-ad-img"
#                                                data-fancybox="gallery"
#                                                data-url="http://www.prepisenergii.cz/?utm_source=bezrealitky&amp;utm_medium=banner&amp;utm_campaign=carousel2019"
#
#
#                                             >
#                                                 <img src="/img/innogy/780x500_banner_cs.jpg" width="820" height="545" alt="Innogy">
#                                             </a>
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1555577199-ahbtgjbwgh.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1555577199-ahbtgjbwgh.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 3" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508900-dfhoyncjiy.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508900-dfhoyncjiy.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 4" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508884-iemcevmfuu.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508884-iemcevmfuu.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 5" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532860-jhaniolome.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532860-jhaniolome.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 6" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532974-ysfumkmwsy.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532974-ysfumkmwsy.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 7" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532910-vegjlszwyw.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532910-vegjlszwyw.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 8" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532930-atenwglmdr.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532930-atenwglmdr.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 9" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532869-ttudfsbmvz.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532869-ttudfsbmvz.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 10" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532894-kpmmnjhjqw.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541532894-kpmmnjhjqw.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 11" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1543916256-oxpnvdjsda.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1543916256-oxpnvdjsda.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 12" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508979-ipxfnucrhm.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1553508979-ipxfnucrhm.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 13" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541533038-hfakpttlcu.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1541533038-hfakpttlcu.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 14" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1543916286-hukcjpymdd.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1543916286-hukcjpymdd.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 15" width="820" height="545">
#                                         </a>
#
#
#                                                                                                                     <a href="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1555577107-jzlzlhehbt.jpg" class="carousel__item b-gallery__img-lg__item" data-fancybox="gallery">
#                                             <img src="https://www.bezrealitky.cz/media/cache/record_main/data/record/images/539k/539200/1555577107-jzlzlhehbt.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, obr. č. 16" width="820" height="545">
#                                         </a>
#
#
#                                                                     </div>
#                             </div>
#
#                                                                                         <div class="b-gallery__thumbnails">
#                                     <div class="b-gallery__imgs-sm">
#                                         <div class="slick-detail-thumbs">
#
#                                                                                                 <div class="b-gallery__imgs-sm__item is-active">
#                                                     <span class="b-gallery__imgs-sm__wrap ">
#                                                         <img src="https://www.bezrealitky.cz/media/cache/record_thumb/data/record/images/539k/539200/1541532840-gbkfzblzrc.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, náhled. č. 1" width="136" height="85">
#                                                     </span>
#                                                 </div>
#
#                                                                                                 <div class="b-gallery__imgs-sm__item ">
#                                                     <span class="b-gallery__imgs-sm__wrap ">
#                                                         <img src="https://www.bezrealitky.cz/media/cache/record_thumb/data/record/images/539k/539200/1553508868-piwlwuivqr.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, náhled. č. 2" width="136" height="85">
#                                                     </span>
#                                                 </div>
#                                                                                                                                                                                                 <div class="b-gallery__imgs-sm__item d-none">
#                                                         <span class="b-gallery__imgs-sm__wrap ">
#                                                             <img src="/img/innogy/thumb.jpg" alt="Innogy" width="136" height="85">
#                                                         </span>
#                                                     </div>
#
#                                                                                                 <div class="b-gallery__imgs-sm__item ">
#                                                     <span class="b-gallery__imgs-sm__wrap ">
#                                                         <img src="https://www.bezrealitky.cz/media/cache/record_thumb/data/record/images/539k/539200/1555577199-ahbtgjbwgh.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, náhled. č. 3" width="136" height="85">
#                                                     </span>
#                                                 </div>
#
#                                                                                                 <div class="b-gallery__imgs-sm__item ">
#                                                     <span class="b-gallery__imgs-sm__wrap d-none d-sm-inline-block">
#                                                         <img src="https://www.bezrealitky.cz/media/cache/record_thumb/data/record/images/539k/539200/1553508900-dfhoyncjiy.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, náhled. č. 4" width="136" height="85">
#                                                     </span>
#                                                 </div>
#
#                                                                                                 <div class="b-gallery__imgs-sm__item ">
#                                                     <span class="b-gallery__imgs-sm__wrap d-none d-sm-inline-block">
#                                                         <img src="https://www.bezrealitky.cz/media/cache/record_thumb/data/record/images/539k/539200/1553508884-iemcevmfuu.jpg" alt="Prodej bytu 3+kk, 88 m², Tetínská, Praha - Radlice, Praha, náhled. č. 5" width="136" height="85">
#                                                     </span>
#                                                 </div>
#                                                                                                                                     </div>
#                                     </div>
#
#                                                                             <div class="b-gallery__more">
#                                             <div class="b-gallery__more-link js-fancybox-more">
#                                                 <span class="icon-svg icon-svg--camera ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-camera" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                                +11 dalších
#                                             </div>
#                                         </div>
#                                                                     </div>
#                                                     </div>
#
#                         <nav class="m-waypoints m-waypoints--border">
#                             <ul class="m-waypoints__list">
#                                 <li class="m-waypoints__item">
#                                     <a href="#popis" class="m-waypoints__link js-scroll">
#                                         Popis a parametry
#                                         <span class="icon-svg icon-svg--arrow-down ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-arrow-down" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                    </a>
#                                 </li>
#                                 <li class="m-waypoints__item">
#                                     <a href="#mapa" class="m-waypoints__link js-scroll map-menu-link">
#                                         Mapa
#                                         <span class="icon-svg icon-svg--arrow-down ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-arrow-down" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                    </a>
#                                 </li>
#                                 <li class="m-waypoints__item">
#                                     <a href="#podobne" class="m-waypoints__link js-scroll">
#                                         Podobné inzeráty v okolí
#                                         <span class="icon-svg icon-svg--arrow-down ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-arrow-down" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                                    </a>
#                                 </li>
#                             </ul>
#                         </nav>
#
#                         <div class="b-desc" data-element="detail-description">
#                             <h2 id="popis">Popis</h2>
#                             <p class="b-desc__info">
# ...
#                                     <li class="m-footer__item">
#                                         <a href="/vypis/nabidka-pronajem/byt/praha" class="m-footer__link">Pronájem bytu v Praze</a>
#                                     </li>
#                                     <li class="m-footer__item">
#                                         <a href="/vypis/nabidka-prodej/byt/jihomoravsky-kraj/okres-brno-mesto" class="m-footer__link">Prodej bytu v Brně</a>
#                                     </li>
#                                     <li class="m-footer__item">
#                                         <a href="/vypis/nabidka-prodej/byt/moravskoslezsky-kraj/okres-ostrava-mesto" class="m-footer__link">Prodej bytu v Ostravě</a>
#                                     </li>
#                                     <li class="m-footer__item">
#                                         <a href="/vypis/nabidka-prodej/byt/plzensky-kraj/okres-plzen-mesto" class="m-footer__link">Prodej bytu v Plzni</a>
#                                     </li>
#                                 </ul>
#
#                                                             </nav>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#
#                         <div class="col col-12 mx-auto col-md-6 col-lg-5 col-xl-4">
#                 <div class="box">
#                     <div class="card card--rescue">
#     <div class="card-body">
#         <h3 class="h4 color-green mb-30 text-center">Nevíte si rady?</h3>
#
#         <div class="row">
#             <div class="col col-12 col-sm-auto text-center">
#                 <span class="avatar avatar-md mb-20 mb-md-0">
#                     <span class="avatar__img">
#                         <img src="/img/cc-team.jpg" alt="">
#                     </span>
#                 </span>
#             </div>
#
#             <div class="col text-center text-sm-left pr-sm-75">
#                 <div class="row no-gutters">
#                     <div class="col-12 ml-4">
#                         <p>
#                             <strong class="font-size-15">Tým Bezrealitky</strong><br>
#                             <span class="font-size-13 color-gray">Zákaznická péče</span>
#                         </p>
#                     </div>
#
#                     <div class="col-12">
#                         <p>
#                             <span class="item-ico item-ico--before">
#                                 <span class="icon-svg icon-svg--phone ">
#                                     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                         <use xlink:href="/img/bg/icons-svg.svg#icon-phone" x="0" y="0" width="100%" height="100%"></use>
#                                     </svg>
#                                 </span>
#
#                                 +420 226 227 522
#                             </span><br>
#                             <span class="color-gray pl-20 font-size-13 pl-25">
#                                 Po - Pá (8:00 - 18:00)
#                             </span>
#                         </p>
#
#                         <p class="mb-0">
#                             <a href="mailto:info@bezrealitky.cz?subject=Nová zpráva od návštěvníka Bezrealitky">
#                                 <span class="item-ico item-ico--before">
#                                     <span class="icon-svg icon-svg--envelope ">
#                                         <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                                             <use xlink:href="/img/bg/icons-svg.svg#icon-envelope" x="0" y="0" width="100%" height="100%"></use>
#                                         </svg>
#                                     </span>
#
#                                     info@bezrealitky.cz
#                                 </span>
#                             </a>
#                         </p>
#                     </div>
#                 </div>
#             </div>
#
#             <div class="col-12 pt-3">
#             </div>
#         </div>
#     </div>
# </div>                </div>
#             </div>
#
#             <div class="col col-12 col-md-6 col-lg-7 col-xl-12">
#
#                 <p class="b-socials b-socials--border mb-30 mb-md-50 text-center">
#                     <a href="https://www.facebook.com/bezrealitky" class="b-socials__link" target="_blank">
#                         <span class="icon-svg icon-svg--facebook ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-facebook" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                    </a>
#                     <a href="https://www.instagram.com/bezrealitky.cz" class="b-socials__link" target="_blank">
#                         <span class="icon-svg icon-svg--instagram ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-instagram" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                    </a>
#                     <a href="https://twitter.com/bezrealitky_cz" class="b-socials__link" target="_blank">
#                         <span class="icon-svg icon-svg--twitter ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-twitter" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                    </a>
#                     <a href="mailto:info@bezrealitky.cz?subject=Nová zpráva od návštěvníka Bezrealitky" class="b-socials__link">
#                         <span class="icon-svg icon-svg--envelope ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-envelope" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                    </a>
#                 </p>
#
#             </div>
#         </div>
#
#         <div class="mw-900 m-auto">
#             <div class="alert alert-content alert-info text-left pt-20 pb-10 mb-40 mb-lg-60" role="alert">
#                 <div class="row align-items-center">
#                     <div class="col col-12 col-md-auto text-center">
#                         <img src="/img/illust/hammer-sm.png" alt="" width="81" height="64">
#                     </div>
#                     <div class="col text-center text-md-left">
#                         <h3 class="h4 mb-10 mb-sm-0 font-weight-normal">
#                             <strong>Chraňte sebe a svůj majetek před rizikem špatně sepsané smlouvy</strong>.
#                         </h3>
#                         <p class="mb-0">Naši právníci vám připraví smlouvu na míru. Ušetříte se zbytečných starostí a výdajů navíc.</p>
#                     </div>
#                     <div class="col col-12 col-md-auto text-center">
#                         <a href="/centrum-sluzeb/kupni-smlouva" class="btn btn-primary" role="button">
#                             Chci smlouvu
#                         </a>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#                 <h3 class="h4 mb-40">Mediální partneři</h3>
#         <div class="items items--sm-xl">
#             <span class="items__item">
#                 <a href="http://www.rockovyradio.cz/" title="" target="_blank">
#                     <img src="/img/illust/logos/rock-radio.png" alt="Rock rádio" width="104" height="63">
#                 </a>
#             </span>
#
#             <span class="items__item">
#                 <a href="http://www.fajnradio.cz/" title="" target="_blank">
#                     <img src="/img/illust/logos/fajn-radio.png" alt="Fajn radio" width="69" height="56">
#                 </a>
#             </span>
#             <span class="items__item">
#                 <a href="https://hitradio.cz/" title="" target="_blank">
#                     <img src="/img/illust/logos/hitradio.png" alt="Hitradio" width="104" height="54">
#                 </a>
#             </span>
#             <span class="items__item">
#                 <a href="http://www.radioblanik.cz/" title="" target="_blank">
#                     <img src="/img/illust/logos/blanik-radio.png" alt="Blanik rádio" width="58" height="54">
#                 </a>
#             </span>
#             <span class="items__item">
#                 <a href="https://www.living.cz/" title="" target="_blank">
#                     <img src="/img/illust/logos/living.png" alt="Living" width="116" height="26">
#                 </a>
#             </span>
#         </div>
#
#         <div class="box__separator mb-30 mt-30 mt-md-60"></div>
#
#         <h3 class="h4 mb-20 mb-md-10">U nás lze hradit služby vícero&nbsp;způsoby</h3>
#         <div class="row">
#             <div class="col col-sm-7 col-md-12 mx-auto">
#                 <div class="items items--lg">
#                                         <span class="items__item">
#                         <span class="item-ico item-ico--before">
#                             <span class="icon-svg icon-svg--monitor ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-monitor" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            Internetovým bankovnictvím
#                         </span>
#                     </span>
#
#                     <span class="items__item">
#                         <span class="item-ico item-ico--before">
#                             <span class="icon-svg icon-svg--card ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-card" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            Kartou
#                         </span>
#                     </span>
#
#                                         <span class="items__item">
#                         <span class="item-ico item-ico--before">
#                             <span class="icon-svg icon-svg--transfer ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-transfer" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            Převodem
#                         </span>
#                     </span>
#
#                                         <span class="items__item">
#                         <span class="item-ico item-ico--before">
#                             <span class="icon-svg icon-svg--foldout ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-foldout" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            Složenkou
#                         </span>
#                     </span>
#
#                     <span class="items__item">
#                         <span class="item-ico item-ico--before">
#                             <span class="icon-svg icon-svg--mobile ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-mobile" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            SMS
#                         </span>
#                     </span>
#
#                     <span class="items__item">
#                         <span class="item-ico item-ico--before">
#                             <span class="icon-svg icon-svg--logo-default ">
#     <svg class="icon-svg__svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use xlink:href="/img/bg/icons-svg.svg#icon-logo-default" x="0" y="0" width="100%" height="100%"></use>
#     </svg>
# </span>                            Bezrealitky peněženkou
#                         </span>
#                     </span>
#                 </div>
#             </div>
#         </div>
#
#         <div class="box__separator mb-20 mt-30"></div>
#
#         <div class="row color-gray text-sm-left font-size-13 mb-20">
#             <div class="col">
#                 <p>&copy; 2007–2019 <br class="d-sm-none"> Bezrealitky - Všechna práva vyhrazena</p>
#             </div>
#
#             <div class="col col-12 col-sm-auto text-sm-right">
#                 <p>
#                     <a href="https://www.id-sign.com" target="_blank" title="Tvorba webových stránek">
#                         Tvorba webových stránek iD-SIGN
#                     </a>
#                 </p>
#             </div>
#         </div>
#     </div>
# </footer>
#
#         <!--[if (gte IE 9) | (!IE)]><!-->
#         <script src="/js/jquery-2.2.4.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.0/umd/popper.min.js" integrity="sha384-cs/chFZiN24E4KMATLdqdvsezGxaGsi4hLGOzlXwp5UZB1LY//20VyM2taTB4QvJ" crossorigin="anonymous"></script>
#         <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" crossorigin="anonymous"></script>
#         <script>
#
#         </script>
#         <!--<![endif]-->
#
#         <script>
#             var BASE_URL = '/';
#             var BZR_ACCESS_TOKEN = '';
#
#             window.bzrLocalStorage.setItem('bzrAccessToken', BZR_ACCESS_TOKEN);
#         </script>
#
#             <script>
#         $(document).ready(function () {
#             $('#show_english_description').on('click', englishDescription);
#         });
#
#         var englishDescription = function (e) {
#             e.preventDefault();
#             $('#english_description').toggleClass('d-none');
#
#             return false;
#         };
#     </script>
#
#     <script src="https://www.google.com/recaptcha/api.js"></script>
#     <script src="/build/commons.70a2419c.js"></script>
#     <script src="/build/detail.b014b8bb.js" async defer></script>
#
#                 <script>
#             $('a[data-utm-medium]').click(function(event) {
#                 event.preventDefault();
#                 var link = $(this);
#
#                 setTimeout(function() {
#                     dataLayer.push({
#                         'event': 'trackClickEvent',
#                         'eventAction': link.data('utm-medium'), // utm_medium
#                         'eventLabel': link.data('utm-campaign'), // utm_campaign
#                         'eventValue': 1,
#                     });
#
#                     if (!link.data('fancybox')) { // sconto gallery ad
#                         window.location.href = link.attr('href');
#                     }
#                 }, 300);
#             });
#         </script>
#
#                 <script>
#             window.addEventListener("load", function(){
#                 if (typeof window.cookieconsent === 'undefined') {
#                     return;
#                 }
#
#                 window.cookieconsent.initialise({
#                     "palette": {
#                         "popup": {
#                             "background": "#5a5a5a",
#                             "text": "#ffffff"
#                         },
#                         "button": {
#                             "background": "#85b542",
#                             "text": "#ffffff"
#                         }
#                     },
#                     "content": {
#                         "message": "Na tomto webu zpracováváme cookies potřebné pro jeho fungování a analytiku, v případě udělení souhlasu také cookies pro účely cílení reklamy a personalizaci reklam. K tomu využíváme své partnery pro sociální média, inzerci a analýzy. Více informací o nastavení cookies naleznete",
#                         "dismiss": "V pořádku",
#                         "link": "zde.",
#                         "href": "/informace/cookies"
#                     }
#                 })});
#         </script>
#
#
#         <script type="text/javascript">
#             if (typeof _satellite === 'object') {
#                 _satellite.pageBottom();
#             }
#         </script>
#     </body>
# </html>

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')

# %%
house_containers = html_soup.find_all('span', class_="items__item")

# %%
print(house_containers)
# Out:
# []

# %%
first = house_containers[0]
first.find_all('span')
# Out:
# [<span class="messengerOFFLINE" id="MC_PropertyInList_repProperties_spanMessenger_0" onclick="goToMessenger('/0d21bf8e-766e-11e9-9763-060000000053.html');" style="cursor: pointer;">
#  <i class="fa fa-comment fa-lg"></i>
#  </span>, <span>
#                          Apartamento T3, Bairro das Colónias (Anjos), Arroios, Lisboa
#                      </span>, <span class="btnContactPVPI" id="MC_PropertyInList_repProperties_btnContactPVPINormal_0" onclick="ShowContactForm('0d21bf8e-766e-11e9-9763-060000000053', '13', '5', true); return false;" style="z-index: 9999;">Contacte Anunciante</span>, <span>310 000 <strong title="Euro">€</strong></span>]

# %%
titles = []
created = []
prices = []
areas = []
zone = []
condition = []
descriptions = []
urls = []
thumbnails = []

# %%
# %%time

n_pages = 0

for page in range(0,900):
    n_pages += 1
    sapo_url = 'https://casa.sapo.pt/Venda/Apartamentos/?sa=11&lp=10000&or=10'+'&pn='+str(page)
    r = get(sapo_url, headers=headers)
    page_html = BeautifulSoup(r.text, 'html.parser')
    house_containers = page_html.find_all('div', class_="searchResultProperty")
    if house_containers != []:
        for container in house_containers:
            
            # Price            
            price = container.find_all('span')[2].text
            if price == 'Contacte Anunciante':
                price = container.find_all('span')[3].text
                if price.find('/') != -1:
                    price = price[0:price.find('/')-1]
            if price.find('/') != -1:
                price = price[0:price.find('/')-1]
            
            price_ = [int(price[s]) for s in range(0,len(price)) if price[s].isdigit()]
            price = ''
            for x in price_:
                price = price+str(x)
            prices.append(int(price))

            # Zone
            location = container.find_all('p', class_="searchPropertyLocation")[0].text
            location = location[7:location.find(',')]
            zone.append(location)

            # Title
            name = container.find_all('span')[0].text
            titles.append(name)

            # Status
            status = container.find_all('p')[5].text
            condition.append(status)

            # Area
            m2 = container.find_all('p')[9].text
            if m2 != '-':
                m2 = m2.replace('\xa0','')
                m2 = float("".join(itertools.takewhile(str.isdigit, m2)))
                areas.append(m2)
                
            else:
                m2 = container.find_all('p')[7].text
                if m2 != '-':
                    m2 = m2.replace('\xa0','')
                    m2 = float("".join(itertools.takewhile(str.isdigit, m2)))
                    areas.append(m2)
                else:
                    areas.append(m2)

            # Creation date
            date = pd.to_datetime(container.find_all('div', class_="searchPropertyDate")[0].text[21:31])
            created.append(date)

            # Description
            desc = container.find_all('p', class_="searchPropertyDescription")[0].text[7:-6]
            descriptions.append(desc)

            # url
            link = 'https://casa.sapo.pt/' + container.find_all('a')[0].get('href')[1:-6]
            urls.append(link)

            # image
            img = str(container.find_all('img')[0])
            img = img[img.find('data-original_2x=')+18:img.find('id=')-2]
            thumbnails.append(img)
    else:
        break
    
    sleep(randint(1,2))
    
print('You scraped {} pages containing {} properties.'.format(n_pages, len(titles)))
